# %% [markdown]
# # Array

# %%
import array

a = array.array('d', [1.2, 1.3, 2.3])
print(a)
print(type(a))
print(id(a))
print(id(a[2]))
# Out:
# array('d', [1.2, 1.3, 2.3])
# <class 'array.array'>
# 2146647635296
# 2146640401520

# %%
import array as arr

a = arr.array('d', [1.2, 1.3, 2.3])
a.append(3.4)
print(a)
a.extend([4.5, 6.3, 6.8])
print(a)
a.insert(2, 3.8)
print(a)
# Out:
# array('d', [1.2, 1.3, 2.3, 3.4])
# array('d', [1.2, 1.3, 2.3, 3.4, 4.5, 6.3, 6.8])
# array('d', [1.2, 1.3, 3.8, 2.3, 3.4, 4.5, 6.3, 6.8])
